# %% [markdown]
# # KNR ROBOBUDEX

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import pandas as pd
import ecoinfo
from rules import *
import rasterio

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# %% [markdown]
# ### DATASET & DATALOADER

# %%
class USADataset(Dataset):
    def __init__(self):
        self.sampling_lat = 200
        self.sampling_lon = 400 
        self.lendata = 0
        self.data = self.generate_data()
        
        

    def generate_data(self):
        latitudes = torch.linspace(25.0, 49.5, self.sampling_lat)
        longtitudes = torch.linspace(-125.0, -67.0, self.sampling_lon)
        data = torch.zeros((self.sampling_lat * self.sampling_lon, 7), dtype=torch.float32)
        sample_idx = 0
        raster_map = ecoinfo.get_default_params_map()

        df_data = ecoinfo.extract_multiple_to_df(raster_map, [(lat, lon) for lat in latitudes for lon in longtitudes])
        while sample_idx < len(df_data):
            row = df_data.iloc[sample_idx]
            data[sample_idx, 0:] = torch.tensor([
                row["lat"],
                row["lon"],  
                row["Wind efficiency"],
                row["Solar power"],
                row["Fiber optics"],
                row["Temperature"],
                row["Popilation density"]
            ], dtype=torch.float32)
            sample_idx += 1

        self.lendata = sample_idx
        data=data[0:self.lendata,:]
        return data
                
                    
        
    def __len__(self):
        return self.lendata

    def __getitem__(self, idx):
        return self.data[idx,:]
        
dataset = USADataset()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 43
#      40     def __getitem__(self, idx):
#      41         return self.data[idx,:]
# ---> 43 dataset = USADataset()
#
# Cell In[10], line 6, in USADataset.__init__(self)
#       4 self.sampling_lon = 400
#       5 self.lendata = 0
# ----> 6 self.data = self.generate_data()
#
# Cell In[10], line 17, in USADataset.generate_data(self)
#      14 sample_idx = 0
#      15 raster_map = ecoinfo.get_default_params_map()
# ---> 17 df_data = ecoinfo.extract_multiple_to_df(raster_map, [(lat, lon) for lat in latitudes for lon in longtitudes])
#      18 while sample_idx < len(df_data):
#      19     row = df_data.iloc[sample_idx]
#
# File ~/Desktop/BHeL/besthackingleague2025/ecoinfo.py:59, in extract_multiple_to_df(raster_map, coordinates, named_mode, calculate_avgs, calculate_stdevs)
#      57     for value_name, path in raster_map.items():
#      58         with rasterio.open(path) as src:
# ---> 59             row[value_name] = extract_value(src, lat, lon)
#      61     rows.append(row)
#      63 # Build DF
#
# File ~/Desktop/BHeL/besthackingleague2025/ecoinfo.py:20, in extract_value(src, lat, lon)
#      17 if row < 0 or col < 0 or row >= src.height or col >= src.width:
#      18     return None
# ---> 20 value = src.read(1, window=((row, row+1), (col, col+1)))[0, 0]
#      22 # check against raster's NoData
#      23 if src.nodata is not None and value == src.nodata:
#
# File rasterio/_io.pyx:644, in rasterio._io.DatasetReaderBase.read()
#
# File rasterio/_io.pyx:969, in rasterio._io.DatasetReaderBase._read()
#
# File rasterio/_io.pyx:199, in rasterio._io.io_multi_band()
#
# File /usr/lib/python3.10/contextlib.py:139, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136     except StopIteration:
#     137         raise RuntimeError("generator didn't yield") from None
# --> 139 def __exit__(self, typ, value, traceback):
#     140     if typ is None:
#     141         try:
#
# KeyboardInterrupt:

# %%
torch.save(dataset.data, "usa_dataset_200_400.pt")

# %%
class USADatasetLoaded(Dataset):
    def __init__(self, path):
        self.data = torch.load(path).data    
        self.lendata = self.data.shape[0]

    def __len__(self):
        return self.lendata

    def __getitem__(self, idx):
        return self.data[idx, :]

# %%
dataset = USADatasetLoaded("usa_dataset_200_400_g.pt")

# %%
dataloader = DataLoader(
    dataset,
    batch_size=128,
    shuffle=True
)
print(f"DATASET SHAPE: {len(dataset)}")
# Out:
# DATASET SHAPE: 45779

# %%
print(next(iter(dataloader)))
# Out:
# tensor([[ 2.7216e+01, -8.1682e+01,  3.3524e+01,  4.4760e+00,  3.0566e-01,
#           2.2900e+01,  1.7489e+00],
#         [ 3.8912e+01, -1.1991e+02,  5.0948e+00,  5.1410e+00,  4.1097e-01,
#           2.2000e+00,  0.0000e+00],
#         [ 4.7530e+01, -1.0945e+02,  1.3049e+02,  4.1520e+00,  2.0057e-01,
#           7.3000e+00,  4.4090e-02],
#         [ 3.6450e+01, -8.9677e+01,  6.2268e+01,  4.1340e+00,  3.1495e-01,
#           1.5700e+01,  7.2604e+00],
#         [ 4.2975e+01, -1.0349e+02,  1.0423e+02,  4.5060e+00,  2.1573e-01,
#           9.4000e+00,  0.0000e+00],
#         [ 3.7681e+01, -8.6188e+01,  2.9339e-03,  3.9440e+00,  3.5097e-01,
#           1.4300e+01,  1.1544e+01],
#         [ 3.8543e+01, -8.6043e+01,  4.3298e+01,  3.9260e+00,  4.6912e-01,
#           1.3100e+01,  4.3656e+01],
#         [ 4.4698e+01, -1.1017e+02,  6.3171e+01,  4.4350e+00,  2.1920e-01,
#           3.0000e-01,  0.0000e+00],
#         [ 4.8023e+01, -1.0916e+02,  1.2577e+02,  4.1350e+00,  2.0059e-01,
#           6.6000e+00,  0.0000e+00],
#         [ 4.8884e+01, -1.0247e+02,  8.8142e+01,  4.1780e+00,  2.0518e-01,
#           4.2000e+00,  1.0658e+00],
#         [ 4.9008e+01, -1.0276e+02,  9.8323e+01,  4.1220e+00,  2.0642e-01,
#           4.3000e+00,  1.7311e-01],
#         [ 4.0759e+01, -1.1686e+02,  6.3961e+02,  4.7430e+00,  2.1752e-01,
#           7.2000e+00,  0.0000e+00],
#         [ 4.6545e+01, -1.1570e+02,  7.5224e-02,  3.6630e+00,  2.2413e-01,
#           7.3000e+00,  0.0000e+00],
#         [ 3.9774e+01, -9.8835e+01,  6.9325e+01,  4.4300e+00,  3.9048e-01,
#           1.2000e+01,  1.0428e+00],
#         [ 4.7161e+01, -1.2049e+02,  6.5523e+02,  4.1830e+00,  3.4149e-01,
#           5.4000e+00,  0.0000e+00],
#         [ 4.2975e+01, -1.0668e+02,  1.6319e+02,  4.6460e+00,  2.7594e-01,
#           7.1000e+00,  4.1772e-01],
#         [ 4.3467e+01, -7.6303e+01,  6.0647e-02,  3.5840e+00,  4.3983e-01,
#           2.4400e+01,  4.0173e+01],
#         [ 4.0143e+01, -8.7932e+01,  8.2637e+01,  3.9360e+00,  3.4430e-01,
#           1.1800e+01,  2.2530e+00],
#         [ 3.6327e+01, -8.0664e+01,  4.0462e-01,  4.2130e+00,  3.2358e-01,
#           1.4200e+01,  1.8903e+01],
#         [ 3.6573e+01, -9.7526e+01,  9.9507e+01,  4.4440e+00,  2.5143e-01,
#           1.5600e+01,  0.0000e+00],
#         [ 3.1894e+01, -8.3571e+01,  1.3595e+01,  4.3770e+00,  3.7610e-01,
#           1.9000e+01,  3.0063e+00],
#         [ 3.0048e+01, -1.0392e+02,  3.8936e+01,  5.1980e+00,  3.2625e-01,
#           1.8000e+01,  0.0000e+00],
#         [ 4.5068e+01, -8.8078e+01,  5.2679e+01,  3.8990e+00,  2.7855e-01,
#           7.3000e+00,  2.5464e+01],
#         [ 3.5219e+01, -1.0596e+02,  1.0067e+02,  5.3230e+00,  2.8244e-01,
#           1.1400e+01,  8.6548e-02]])

# %% [markdown]
# ### MODEL

# %%
input_dim = 7
lr = 5e-4
epochs = 100

# %%
def ranknet_loss(score_a, score_b, S):
    """
    score_a, score_b: predicted scores for pairs
    S: target preference (+1 if a > b, -1 if a < b)
    """
    pred = torch.sigmoid(score_a - score_b)
    target = (S + 1) / 2
    loss = nn.BCELoss()(pred, target, )
    return loss


def generate_pairs(batch):
    """
    Generates all pairs from a batch (a,b) for ranking.
    """
    xa = batch.unsqueeze(1).repeat(1, batch.size(0), 1)  # [B,B,F]
    xb = batch.unsqueeze(0).repeat(batch.size(0), 1, 1)  # [B,B,F]

    # Only take upper triangular pairs to avoid duplicates and self-pairs
    mask = torch.triu(torch.ones(xa.shape[0], xa.shape[1]), diagonal=1).bool()
    xa_pairs = xa[mask]
    xb_pairs = xb[mask]
    return xa_pairs, xb_pairs

# %%
class RankNet(nn.Module):
    def __init__(self, input_dim):
        super(RankNet, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )
        
    def forward(self, x):
        return self.model(x)

model = RankNet(input_dim=input_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.7)

# training loop

for epoch in range(epochs):
    total_loss = 0
    for batch in dataloader:
        batch = batch.to(device)
        
        xa, xb = generate_pairs(batch)
        
        S = total_rule_score(xa, xb, N=5)
        S = S.unsqueeze(1)
        S_binary = torch.sign(S).clamp(min=-1.0, max=1.0)
        
        score_a = model(xa)
        score_b = model(xb)
        
        loss = ranknet_loss(score_a, score_b, S_binary)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
    scheduler.step()

    if (epoch%10 == 0):
        print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(dataloader):.4f}")

        #test:
        with torch.no_grad():
            batch = batch.to(device)
        
            xa, xb = generate_pairs(batch)
            
            S = total_rule_score(xa, xb, N=8)
            S = S.unsqueeze(1)
            S_binary = torch.sign(S).clamp(min=-1.0, max=1.0)
            
            score_a = model(xa)
            score_b = model(xb)
            
            loss = ranknet_loss(score_a, score_b, S_binary).item()
            
            print(f" Test Loss (all rules): {loss:.4f}")
# Out:
# Epoch 1/100, Loss: 0.4745
#  Test Loss (all rules): 0.3300
# Epoch 11/100, Loss: 0.3975
#  Test Loss (all rules): 0.2817
# Epoch 21/100, Loss: 0.4044
#  Test Loss (all rules): 0.2759
# Epoch 31/100, Loss: 0.3960
#  Test Loss (all rules): 0.2769
# Epoch 41/100, Loss: 0.4060
#  Test Loss (all rules): 0.2948
# Epoch 51/100, Loss: 0.3986
#  Test Loss (all rules): 0.2369
# Epoch 61/100, Loss: 0.3933
#  Test Loss (all rules): 0.2682
# Epoch 71/100, Loss: 0.3961
#  Test Loss (all rules): 0.2523
# Epoch 81/100, Loss: 0.4012
#  Test Loss (all rules): 0.2830
# Epoch 91/100, Loss: 0.3916
#  Test Loss (all rules): 0.2622

# %%
torch.save(model.state_dict(), "usa_model_200_400.pt")

# %%
model = RankNet(input_dim=input_dim)
model.load_state_dict(torch.load("usa_model_200_400.pt", map_location="cpu"))
model.eval()
# Out:
# RankNet(
#   (model): Sequential(
#     (0): Linear(in_features=7, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=64, out_features=32, bias=True)
#     (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
data_tensor = dataset.data 

with torch.no_grad():
    predictions = model(data_tensor).squeeze().numpy()

latitudes = data_tensor[:, 0].numpy()
longitudes = data_tensor[:, 1].numpy()

# %%
import matplotlib
matplotlib.use("Agg")   # non-interactive backend
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import griddata

# Define regular grid
grid_lon = np.linspace(-125, -67, 80)
grid_lat = np.linspace(25, 50, 40)
grid_lon2d, grid_lat2d = np.meshgrid(grid_lon, grid_lat)

plt.figure(figsize=(14, 8))

grid_pred = griddata(
    points=np.column_stack((longitudes, latitudes)),
    values=predictions,
    xi=(grid_lon2d, grid_lat2d),
    method="nearest"   # instead of "linear"
)
grid_pred = np.ma.masked_invalid(grid_pred)
img = plt.imshow(grid_pred, extent=[-125,-67,25,50], origin="lower", alpha=0.8)



plt.colorbar(img, label="Predicted Score", shrink=0.7)
plt.title("Model Predictions Across USA")

plt.savefig("usa_predictions_map.png", dpi=220)
print("Saved: usa_predictions_map.png")

# %%
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
import numpy as np

# Włączamy Plotly w Jupyter Notebook
init_notebook_mode(connected=True)

# Przykładowe dane (zamień na swoje)
# longitudes = np.array([...])
# latitudes = np.array([...])
# predictions = np.array([...])

# Tworzymy scatter plot
scatter = go.Scattergeo(
    lon=longitudes,
    lat=latitudes,
    text=[f"Score: {v:.2f}" for v in predictions],  # etykieta przy hover
    marker=dict(
        size=2,
        color=predictions,
        cmin=-3,
        cmax=7,   
        colorscale='Viridis',
        colorbar=dict(title='Predicted Score'),
        line=dict(width=0)
    ),
    mode='markers'
)

# Układ mapy
layout = go.Layout(
    title='Model Predictions Across USA',
    geo=dict(
        scope='usa',             # pokazujemy tylko USA
        projection=dict(type='albers usa'),
        showland=True,
        landcolor='lightgray',
        showcountries=True,
        showsubunits=True,       # pokazuje kontury stanów
        subunitcolor='black'     # kolor konturów stanów
    )
)

fig = go.Figure(data=[scatter], layout=layout)

# Wyświetlamy w notebooku
iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
