# %% [markdown]
# # KNR ROBOBUDEX

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import pandas as pd
import ecoinfo
import rasterio

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# %%
### definicja DataSet

# %%
class USADataset(Dataset):
    def __init__(self):
        self.data = self.generate_data()
        self.sampling_lat = 10**5
        self.sampling_lon = 10**5
        self.datapath
        

    def generate_data(self):
        latitudes = torch.linspace(24.5, 49.0, self.sampling_lat)
        longtitudes = torch.linspace(-125.0, -66.92, self.sampling_lon)
        data = torch.zeros((self.sampling_lat * self.sampling_lon, 3))
        sample_idx = 0
        raster_map = ecoinfo.get_default_params_map()
        
        for lat in latitudes:
            for lon in lontitudes:
                data[sample_idx, 0] = lat
                data[sample_idx, 1] = lon
                data[sample_idx, 2] = ecoinfo.extract_value()
        
    



    
    
    def __len__(self):
        return self.sampling_lat * self.sampling_lon

    def __getitem__(self, idx):
